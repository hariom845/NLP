# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
port_stemmer=PorterStemmer()

# %%
# Tokenization
sentences=nltk.sent_tokenize(paragraph)
print(type(sentences))
# Out:
# <class 'list'>

# %%
## Applying Stopwords and filter and then apply stemming

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [port_stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i]=' '.join(words) # convering all the list of words into sentences

# %%
sentences
# Out:
# ['i stand today humbl task us , grate trust bestow , mind sacrific born ancestor .',
#  'i thank presid bush servic nation , well generos cooper shown throughout transit .',
#  'forty-four american taken presidenti oath .',
#  'the word spoken rise tide prosper still water peac .',
#  'yet , everi often oath taken amidst gather cloud rage storm .',
#  'at moment , america carri simpli skill vision high offic , we peopl remain faith ideal forbear , true found document .',
#  'so .',
#  'so must gener american .',
#  'that midst crisi well understood .',
#  'our nation war , far-reach network violenc hatr .',
#  'our economi badli weaken , consequ greed irrespons part , also collect failur make hard choic prepar nation new age .',
#  'home lost ; job shed ; busi shutter .',
#  'our health care costli ; school fail mani ; day bring evid way use energi strengthen adversari threaten planet .',
#  'these indic crisi , subject data statist .',
#  "less measur less profound sap confid across land - nag fear america 's declin inevit , next gener must lower sight .",
#  'today i say challeng face real .',
#  'they seriou mani .',
#  'they met easili short span time .',
#  'but know , america - met .',
#  'on day , gather chosen hope fear , uniti purpos conflict discord .',
#  'on day , come proclaim end petti grievanc fals promis , recrimin worn dogma , far long strangl polit .',
#  'we remain young nation , word scriptur , time come set asid childish thing .',
#  'the time come reaffirm endur spirit ; choos better histori ; carri forward preciou gift , nobl idea , pass gener gener : god-given promis equal , free , deserv chanc pursu full measur happiness.in reaffirm great nation , understand great never given .',
#  'it must earn .',
#  'our journey never one short-cut settl less .',
#  'it path faint-heart - prefer leisur work , seek pleasur rich fame .',
#  'rather , risk-tak , doer , maker thing - celebr often men women obscur labor , carri us long , rug path toward prosper freedom .',
#  'for us , pack worldli possess travel across ocean search new life .',
#  'for us , toil sweatshop settl west ; endur lash whip plow hard earth .',
#  'for us , fought die , place like concord gettysburg ; normandi khe sahn .',
#  'time men women struggl sacrif work till hand raw might live better life .',
#  'they saw america bigger sum individu ambit ; greater differ birth wealth faction .',
#  'thi journey continu today .',
#  'we remain prosper , power nation earth .',
#  'our worker less product crisi began .',
#  'our mind less invent , good servic less need last week last month last year .',
#  'our capac remain undiminish .',
#  'but time stand pat , protect narrow interest put unpleas decis - time sure pass .',
#  'start today , must pick , dust , begin work remak america .',
#  'for everywher look , work done .',
#  'the state economi call action , bold swift , act - creat new job , lay new foundat growth .',
#  'we build road bridg , electr grid digit line feed commerc bind us togeth .',
#  "we restor scienc right place , wield technolog 's wonder rais health care 's qualiti lower cost .",
#  'we har sun wind soil fuel car run factori .',
#  'and transform school colleg univers meet demand new age .',
#  'all .',
#  'and .',
#  'now , question scale ambit - suggest system toler mani big plan .',
#  'their memori short .',
#  'for forgotten countri alreadi done ; free men women achiev imagin join common purpos , necess courag .',
#  'what cynic fail understand ground shift beneath - stale polit argument consum us long longer appli .',
#  'the question ask today whether govern big small , whether work - whether help famili find job decent wage , care afford , retir dignifi .',
#  'where answer ye , intend move forward .',
#  'where answer , program end .',
#  "and us manag public 's dollar held account - spend wise , reform bad habit , busi light day - restor vital trust peopl government.nor question us whether market forc good ill. it power gener wealth expand freedom unmatch , crisi remind us without watch eye , market spin control - nation prosper long favor prosper .",
#  'the success economi alway depend size gross domest product , reach prosper ; abil extend opportun everi will heart - chariti , surest rout common good .',
#  'as common defens , reject fals choic safeti ideal .',
#  'our found father , face peril scarc imagin , draft charter assur rule law right man , charter expand blood gener .',
#  "those ideal still light world , give expedi 's sake .",
#  'and peopl govern watch today , grandest capit small villag father born : know america friend nation everi man , woman , child seek futur peac digniti , readi lead .',
#  'recal earlier gener face fascism commun missil tank , sturdi allianc endur convict .',
#  'they understood power alon protect us , entitl us pleas .',
#  'instead , knew power grow prudent use ; secur eman just caus , forc exampl , temper qualiti humil restraint .',
#  'we keeper legaci .',
#  'guid principl , meet new threat demand even greater effort - even greater cooper understand nation .',
#  'we begin respons leav iraq peopl , forg hard-earn peac afghanistan .',
#  'with old friend former foe , ’ work tirelessli lessen nuclear threat , roll back specter warm planet .',
#  'we apolog way life , waver defens , seek advanc aim induc terror slaughter innoc , say spirit stronger broken ; outlast us , defeat .',
#  'for know patchwork heritag strength , weak .',
#  'we nation christian muslim , jew hindu - non-believ .',
#  'we shape everi languag cultur , drawn everi end earth ; tast bitter swill civil war segreg , emerg dark chapter stronger unit , help believ old hatr shall someday pass ; line tribe shall soon dissolv ; world grow smaller , common human shall reveal ; america must play role usher new era peac .',
#  'to muslim world , seek new way forward , base mutual interest mutual respect .',
#  "to leader around globe seek sow conflict , blame societi 's ill west - know peopl judg build , destroy .",
#  'to cling power corrupt deceit silenc dissent , know wrong side histori ; extend hand will unclench fist .',
#  'to peopl poor nation , pledg work alongsid make farm flourish let clean water flow ; nourish starv bodi feed hungri mind .',
#  "and nation like enjoy rel plenti , say longer afford indiffer suffer outsid border ; consum world 's resourc without regard effect .",
#  'for world chang , must chang .']

# %% [markdown]
# 2. SnowballStemming+Stopwords

# %%
from nltk.stem import SnowballStemmer
snow_stemmer=SnowballStemmer('english')

# %%
## Applying stopwords and filter and then apply snowball stemming
sentences=nltk.sent_tokenize(paragraph)
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    #words = [port_stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    words=[snow_stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i]=' '.join(words)

# %%
sentences
# Out:
# ['i stand today humbl task us , grate trust bestow , mind sacrific born ancestor .',
#  'i thank presid bush servic nation , well generos cooper shown throughout transit .',
#  'forty-four american taken presidenti oath .',
#  'the word spoken rise tide prosper still water peac .',
#  'yet , everi often oath taken amidst gather cloud rage storm .',
#  'at moment , america carri simpli skill vision high offic , we peopl remain faith ideal forbear , true found document .',
#  'so .',
#  'so must generat american .',
#  'that midst crisi well understood .',
#  'our nation war , far-reach network violenc hatr .',
#  'our economi bad weaken , consequ greed irrespons part , also collect failur make hard choic prepar nation new age .',
#  'home lost ; job shed ; busi shutter .',
#  'our health care cost ; school fail mani ; day bring evid way use energi strengthen adversari threaten planet .',
#  'these indic crisi , subject data statist .',
#  "less measur less profound sap confid across land - nag fear america 's declin inevit , next generat must lower sight .",
#  'today i say challeng face real .',
#  'they serious mani .',
#  'they met easili short span time .',
#  'but know , america - met .',
#  'on day , gather chosen hope fear , uniti purpos conflict discord .',
#  'on day , come proclaim end petti grievanc fals promis , recrimin worn dogma , far long strangl polit .',
#  'we remain young nation , word scriptur , time come set asid childish thing .',
#  'the time come reaffirm endur spirit ; choos better histori ; carri forward precious gift , nobl idea , pass generat generat : god-given promis equal , free , deserv chanc pursu full measur happiness.in reaffirm great nation , understand great never given .',
#  'it must earn .',
#  'our journey never one short-cut settl less .',
#  'it path faint-heart - prefer leisur work , seek pleasur rich fame .',
#  'rather , risk-tak , doer , maker thing - celebr often men women obscur labor , carri us long , rug path toward prosper freedom .',
#  'for us , pack world possess travel across ocean search new life .',
#  'for us , toil sweatshop settl west ; endur lash whip plow hard earth .',
#  'for us , fought die , place like concord gettysburg ; normandi khe sahn .',
#  'time men women struggl sacrif work till hand raw might live better life .',
#  'they saw america bigger sum individu ambit ; greater differ birth wealth faction .',
#  'this journey continu today .',
#  'we remain prosper , power nation earth .',
#  'our worker less product crisi began .',
#  'our mind less invent , good servic less need last week last month last year .',
#  'our capac remain undiminish .',
#  'but time stand pat , protect narrow interest put unpleas decis - time sure pass .',
#  'start today , must pick , dust , begin work remak america .',
#  'for everywher look , work done .',
#  'the state economi call action , bold swift , act - creat new job , lay new foundat growth .',
#  'we build road bridg , electr grid digit line feed commerc bind us togeth .',
#  "we restor scienc right place , wield technolog 's wonder rais health care 's qualiti lower cost .",
#  'we har sun wind soil fuel car run factori .',
#  'and transform school colleg univers meet demand new age .',
#  'all .',
#  'and .',
#  'now , question scale ambit - suggest system toler mani big plan .',
#  'their memori short .',
#  'for forgotten countri alreadi done ; free men women achiev imagin join common purpos , necess courag .',
#  'what cynic fail understand ground shift beneath - stale polit argument consum us long longer appli .',
#  'the question ask today whether govern big small , whether work - whether help famili find job decent wage , care afford , retir dignifi .',
#  'where answer yes , intend move forward .',
#  'where answer , program end .',
#  "and us manag public 's dollar held account - spend wise , reform bad habit , busi light day - restor vital trust peopl government.nor question us whether market forc good ill. it power generat wealth expand freedom unmatch , crisi remind us without watch eye , market spin control - nation prosper long favor prosper .",
#  'the success economi alway depend size gross domest product , reach prosper ; abil extend opportun everi will heart - chariti , surest rout common good .',
#  'as common defens , reject fals choic safeti ideal .',
#  'our found father , face peril scarc imagin , draft charter assur rule law right man , charter expand blood generat .',
#  "those ideal still light world , give expedi 's sake .",
#  'and peopl govern watch today , grandest capit small villag father born : know america friend nation everi man , woman , child seek futur peac digniti , readi lead .',
#  'recal earlier generat face fascism communism missil tank , sturdi allianc endur convict .',
#  'they understood power alon protect us , entitl us pleas .',
#  'instead , knew power grow prudent use ; secur eman just caus , forc exampl , temper qualiti humil restraint .',
#  'we keeper legaci .',
#  'guid principl , meet new threat demand even greater effort - even greater cooper understand nation .',
#  'we begin respons leav iraq peopl , forg hard-earn peac afghanistan .',
#  'with old friend former foe , ’ work tireless lessen nuclear threat , roll back specter warm planet .',
#  'we apolog way life , waver defens , seek advanc aim induc terror slaughter innoc , say spirit stronger broken ; outlast us , defeat .',
#  'for know patchwork heritag strength , weak .',
#  'we nation christian muslim , jew hindus - non-believ .',
#  'we shape everi languag cultur , drawn everi end earth ; tast bitter swill civil war segreg , emerg dark chapter stronger unit , help believ old hatr shall someday pass ; line tribe shall soon dissolv ; world grow smaller , common human shall reveal ; america must play role usher new era peac .',
#  'to muslim world , seek new way forward , base mutual interest mutual respect .',
#  "to leader around globe seek sow conflict , blame societi 's ill west - know peopl judg build , destroy .",
#  'to cling power corrupt deceit silenc dissent , know wrong side histori ; extend hand will unclench fist .',
#  'to peopl poor nation , pledg work alongsid make farm flourish let clean water flow ; nourish starv bodi feed hungri mind .',
#  "and nation like enjoy relat plenti , say longer afford indiffer suffer outsid border ; consum world 's resourc without regard effect .",
#  'for world chang , must chang .']

# %% [markdown]
# 3. Lemmatization+Stopwords

# %%
from nltk.stem import WordNetLemmatizer
word_net_lemmatize = WordNetLemmatizer()

# %% [markdown]
# - Lemmatization doesn't lowerize the words we have to do it manually

# %%
sentences=nltk.sent_tokenize(paragraph)
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [word_net_lemmatize.lemmatize(word.lower(), pos='v') for word in words if word not in set(stopwords.words('english'))]
    sentences[i]=' '.join(words)

# %%
sentences
# Out:
# ['i stand today humble task us , grateful trust bestow , mindful sacrifice bear ancestors .',
#  'i thank president bush service nation , well generosity cooperation show throughout transition .',
#  'forty-four americans take presidential oath .',
#  'the word speak rise tide prosperity still water peace .',
#  'yet , every often oath take amidst gather cloud rag storm .',
#  'at moments , america carry simply skill vision high office , we people remain faithful ideals forbearers , true found document .',
#  'so .',
#  'so must generation americans .',
#  'that midst crisis well understand .',
#  'our nation war , far-reaching network violence hatred .',
#  'our economy badly weaken , consequence greed irresponsibility part , also collective failure make hard choices prepare nation new age .',
#  'home lose ; job shed ; businesses shutter .',
#  'our health care costly ; school fail many ; day bring evidence ways use energy strengthen adversaries threaten planet .',
#  'these indicators crisis , subject data statistics .',
#  "less measurable less profound sap confidence across land - nag fear america 's decline inevitable , next generation must lower sight .",
#  'today i say challenge face real .',
#  'they serious many .',
#  'they meet easily short span time .',
#  'but know , america - meet .',
#  'on day , gather choose hope fear , unity purpose conflict discord .',
#  'on day , come proclaim end petty grievances false promise , recriminations wear dogmas , far long strangle politics .',
#  'we remain young nation , word scripture , time come set aside childish things .',
#  'the time come reaffirm endure spirit ; choose better history ; carry forward precious gift , noble idea , pass generation generation : god-given promise equal , free , deserve chance pursue full measure happiness.in reaffirm greatness nation , understand greatness never give .',
#  'it must earn .',
#  'our journey never one short-cuts settle less .',
#  'it path faint-hearted - prefer leisure work , seek pleasures riches fame .',
#  'rather , risk-takers , doers , makers things - celebrate often men women obscure labor , carry us long , rugged path towards prosperity freedom .',
#  'for us , pack worldly possessions travel across oceans search new life .',
#  'for us , toil sweatshops settle west ; endure lash whip plow hard earth .',
#  'for us , fight die , place like concord gettysburg ; normandy khe sahn .',
#  'time men women struggle sacrifice work till hand raw might live better life .',
#  'they saw america bigger sum individual ambition ; greater differences birth wealth faction .',
#  'this journey continue today .',
#  'we remain prosperous , powerful nation earth .',
#  'our workers less productive crisis begin .',
#  'our mind less inventive , goods service less need last week last month last year .',
#  'our capacity remain undiminished .',
#  'but time stand pat , protect narrow interest put unpleasant decisions - time surely pass .',
#  'start today , must pick , dust , begin work remake america .',
#  'for everywhere look , work do .',
#  'the state economy call action , bold swift , act - create new job , lay new foundation growth .',
#  'we build roads bridge , electric grids digital line fee commerce bind us together .',
#  "we restore science rightful place , wield technology 's wonder raise health care 's quality lower cost .",
#  'we harness sun wind soil fuel cars run factories .',
#  'and transform school colleges universities meet demand new age .',
#  'all .',
#  'and .',
#  'now , question scale ambition - suggest system tolerate many big plan .',
#  'their memories short .',
#  'for forget country already do ; free men women achieve imagination join common purpose , necessity courage .',
#  'what cynics fail understand grind shift beneath - stale political arguments consume us long longer apply .',
#  'the question ask today whether government big small , whether work - whether help families find job decent wage , care afford , retirement dignify .',
#  'where answer yes , intend move forward .',
#  'where answer , program end .',
#  "and us manage public 's dollars hold account - spend wisely , reform bad habit , business light day - restore vital trust people government.nor question us whether market force good ill. its power generate wealth expand freedom unmatched , crisis remind us without watchful eye , market spin control - nation prosper long favor prosperous .",
#  'the success economy always depend size gross domestic product , reach prosperity ; ability extend opportunity every will heart - charity , surest route common good .',
#  'as common defense , reject false choice safety ideals .',
#  'our found father , face peril scarcely imagine , draft charter assure rule law right man , charter expand blood generations .',
#  "those ideals still light world , give expedience 's sake .",
#  'and people governments watch today , grandest capitals small village father bear : know america friend nation every man , woman , child seek future peace dignity , ready lead .',
#  'recall earlier generations face fascism communism missiles tank , sturdy alliances endure convictions .',
#  'they understand power alone protect us , entitle us please .',
#  'instead , know power grow prudent use ; security emanate justness cause , force example , temper qualities humility restraint .',
#  'we keepers legacy .',
#  'guide principles , meet new threats demand even greater effort - even greater cooperation understand nations .',
#  'we begin responsibly leave iraq people , forge hard-earned peace afghanistan .',
#  'with old friends former foes , ’ work tirelessly lessen nuclear threat , roll back specter warm planet .',
#  'we apologize way life , waver defense , seek advance aim induce terror slaughter innocents , say spirit stronger break ; outlast us , defeat .',
#  'for know patchwork heritage strength , weakness .',
#  'we nation christians muslims , jews hindus - non-believers .',
#  'we shape every language culture , draw every end earth ; taste bitter swill civil war segregation , emerge dark chapter stronger unite , help believe old hatreds shall someday pass ; line tribe shall soon dissolve ; world grow smaller , common humanity shall reveal ; america must play role usher new era peace .',
#  'to muslim world , seek new way forward , base mutual interest mutual respect .',
#  "to leaders around globe seek sow conflict , blame society 's ills west - know people judge build , destroy .",
#  'to cling power corruption deceit silence dissent , know wrong side history ; extend hand will unclench fist .',
#  'to people poor nations , pledge work alongside make farm flourish let clean water flow ; nourish starve body fee hungry mind .',
#  "and nations like enjoy relative plenty , say longer afford indifference suffer outside border ; consume world 's resources without regard effect .",
#  'for world change , must change .']
